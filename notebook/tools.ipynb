# %%
print("🚀 サポートボットMVP - クイックスタートガイド")
print("=" * 50)
print("")
print("1. 🐳 ベクトルDBを起動:")
print("   make setup-db")
print("")
print("2. 📚 インデックスを作成:")
print("   make create-index")
print("")
print("3. 🚀 APIサーバーを起動:")
print("   make run-api")
print("")
print("4. 🌐 Webインターフェースを起動:")
print("   make run-ui")
print("")
print("5. 🔗 アクセス:")
print(f"   - API: http://{config.APP_HOST}:{config.APP_PORT}/docs")
print("   - UI: http://localhost:8501")
print("")
print("📝 利用可能なコマンド:")
print("   make create-index    # インデックス作成")
print("   make delete-index    # インデックス削除")
print("   make run-api         # APIサーバー起動")
print("   make run-ui          # Webインターフェース起動")
print("   make setup-db        # ベクトルDB起動")
print("")
print("💡 質問例:")
print("   - 勤怠管理システムにログインできません")
print("   - 有給申請はどこから行いますか？")
print("   - 会議室の予約方法を教えてください")
print("   - 経費精算の締め切りはいつですか？")
# Out:
# 🚀 サポートボットMVP - クイックスタートガイド
# ...
#
# 1. 🐳 ベクトルDBを起動:
#    make setup-db
#
# 2. 📚 インデックスを作成:
#    make create-index
#
# 3. 🚀 APIサーバーを起動:
#    make run-api
#
# 4. 🌐 Webインターフェースを起動:
#    make run-ui
#
# 5. 🔗 アクセス:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      15 print("")
#      16 print("5. 🔗 アクセス:")
# ---> 17 print(f"   - API: http://{config.APP_HOST}:{config.APP_PORT}/docs")
#      18 print("   - UI: http://localhost:8501")
#      19 print("")
#
# NameError: name 'config' is not defined

# %%
import sys
import os
from pathlib import Path
import asyncio
import pandas as pd
import json
from datetime import datetime
import requests
import time

# プロジェクトルートを追加
project_root = Path().absolute().parent
sys.path.append(str(project_root))

print(f"📁 プロジェクトルート: {project_root}")
print(f"🐍 Python version: {sys.version}")

# 必要なモジュールをインポート
from src.configs import config
from src.custom_logger import get_module_logger
from src.models import QuestionRequest, AnswerResponse

logger = get_module_logger("notebook_tools")
print("✅ モジュールのインポートが完了しました")
# Out:
# 📁 プロジェクトルート: C:\プログラミング\claudecode13  (サポートセンター)
# 🐍 Python version: 3.12.7 (tags/v3.12.7:0b05ead, Oct  1 2024, 03:06:41) [MSC v.1941 64 bit (AMD64)]
# Traceback (most recent call last):
#
#   File C:\プログラミング\claudecode13  (サポートセンター)\myproject\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 19
#     from src.configs import config
#
#   File C:\プログラミング\claudecode13  (サポートセンター)\src\__init__.py:1
#     """
#     ^
# SyntaxError: (unicode error) 'utf-8' codec can't decode byte 0xb5 in position 26: invalid start byte

# %% [markdown]
# # 🛠️ Support Bot Tools & Testing
#
# サポートボットの動作確認とテストツール集
